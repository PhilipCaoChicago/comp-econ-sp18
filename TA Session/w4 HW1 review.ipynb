# %% [markdown]
# # copy the data before change it

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
face = misc.face(gray=True).astype('float64')
print("The dimensions of face are", face.shape)
facenew = np.sin(face/25)
plt.imshow(facenew,cmap=plt.cm.gray)
# Out:
# The dimensions of face are (768, 1024)
